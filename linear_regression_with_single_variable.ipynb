# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv('sample.csv')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline

# %%
plt.scatter(df.area,df.price,color='blue')
plt.xlabel('area')
plt.ylabel('price')
plt.show()

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# C:\Users\Yuva shree\desktop\machine_learning_practice\.venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
y=135.78767123*3300 + 180616.43835616432
y
# Out:
# 628715.7534151643

# %%
d=pd.read_csv('sample1.csv')
d
# Out:
#    area
# 0  2000
# 1  2200
# 2  2400
# 3  2600
# 4  2800
# 5  3000
# 6  3200
# 7  3400
# 8  3600
# 9  3800

# %%
g=reg.predict(d)
g
# Out:
# array([452191.78082192, 479349.31506849, 506506.84931507, 533664.38356164,
#        560821.91780822, 587979.45205479, 615136.98630137, 642294.52054795,
#        669452.05479452, 696609.5890411 ])

# %%
d['price']=g
d
# Out:
#    area          price
# 0  2000  452191.780822
# 1  2200  479349.315068
# 2  2400  506506.849315
# 3  2600  533664.383562
# 4  2800  560821.917808
# 5  3000  587979.452055
# 6  3200  615136.986301
# 7  3400  642294.520548
# 8  3600  669452.054795
# 9  3800  696609.589041

# %%
d.to_csv('sample1.csv',index=False)

# %%
# %matplotlib inline
plt.plot(df['area'],reg.predict(df[['area']]),color='blue')
plt.xlabel('area')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')
